# %% [markdown]
# # How to import custom modules (.py files) from google drive in google colab
#
# - toc: true
# - badges: true
# - categories: [Python Hacks, Colab]
# - permalink: /import-custom-modules-from-gdrive-in-google-colab/

# %%
#hide
# # run this cell to create example files
# import os
# import gdown
# try:
#   os.makedirs('/content/drive/MyDrive/example_folder')
# except OSError as error: 
#     print(error)

# url = 'https://drive.google.com/file/d/1RZdEywRVhICsfYPeV0j9vepXcYClfZFV/view?usp=sharing'
# output_path = '/content/drive/MyDrive/example_folder/mymodule.py'
# gdown.download(url, output_path, quiet=False,fuzzy=True)
# Out:
# [Errno 17] File exists: '/content/drive/MyDrive/example_folder'
# Downloading...
# From: https://drive.google.com/uc?id=1RZdEywRVhICsfYPeV0j9vepXcYClfZFV
# To: /content/drive/MyDrive/example_folder/mymodule.py
# 100%|██████████| 45.0/45.0 [00:00<00:00, 28.5kB/s]
# '/content/drive/MyDrive/example_folder/mymodule.py'

# %% [markdown]
# ## 1. Mount your google drive in google colab

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %% [markdown]
# ## 2. Append the directory to your python path
# For example, if you want to import a **.py** file called `mymodule.py` in your google drive, which is saved in "/content/drive/MyDrive/example_folder", you need to add the path of the directory which saves `mymodule.py` to system path.

# %%
#collapse-output
from pathlib import Path
# the path of the directory which saves your .py file
src_dir = Path('/content/drive/MyDrive/example_folder/')

# add the path to system path
import sys
try:
  sys.path.index(str(src_dir))
except ValueError:
  sys.path.insert(0,str(src_dir))

# print system path
sys.path
# Out:
# ['/content/drive/MyDrive/example_folder',
#  '',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# <br><br><br>
# After you follow the above steps, you should see `/content/drive/MyDrive/example_folder` in `sys.path`.
#
# Now, try to import your custom module:

# %%
from mymodule import welcome
welcome()
# Out:
# Nice to meet you!
